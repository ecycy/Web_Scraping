# %%
from urllib import *
from bs4 import BeautifulSoup
html = request.urlopen(url).read()
soup = BeautifulSoup(html, 'html.parser')
table_001 = soup.select_one("#container > div.con_wrap > div.contents_wrap > div > div.tab01_con_wrap > table:nth-child(2)")
World = soup.select_one("#container > div.con_wrap > div.contents_wrap > div > div.tab01_con_wrap > table:nth-child(2) > tbody > tr:nth-child(1) > td:nth-child(2) > span").text
Like = table_001.select_one("#container > div.con_wrap > div.contents_wrap > div > div.tab01_con_wrap > table:nth-child(2) > tbody > tr:nth-child(2) > td:nth-child(2) > span").text
Meso = table_001.select_one("#container > div.con_wrap > div.contents_wrap > div > div.tab01_con_wrap > table:nth-child(2) > tbody > tr:nth-child(3) > td:nth-child(2) > span").text
Job = table_001.select_one("#container > div.con_wrap > div.contents_wrap > div > div.tab01_con_wrap > table:nth-child(2) > tbody > tr:nth-child(1) > td:nth-child(4) > span").text
Guild = table_001.select_one("#container > div.con_wrap > div.contents_wrap > div > div.tab01_con_wrap > table:nth-child(2) > tbody > tr:nth-child(2) > td:nth-child(4) > span").text
MaplePoint = table_001.select_one("#container > div.con_wrap > div.contents_wrap > div > div.tab01_con_wrap > table:nth-child(2) > tbody > tr:nth-child(3) > td:nth-child(4) > span").text
print(f"월드           {World}")
print(f"인기도         {Like}")
print(f"메소           {Meso}")
print(f"직업           {Job}")
print(f"길드           {Guild}")
print(f"메이플포인트    {MaplePoint}")
# Out:
# 월드           이노시스
# 인기도         1,145
# 메소           129,591,677
# 직업           카이저
# 길드           프라하
# 메이플포인트    154,306
